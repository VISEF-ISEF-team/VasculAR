# %% [markdown]
# # **Phát hiện và khoanh vùng bất thường động mạch vành**
#
# ## **Bình thường**
# <img src="https://github.com/VISEF-ISEF-team/VascuIAR/blob/main/imgs/Ph%C3%A1t%20hi%E1%BB%87n%20b%E1%BB%87nh/%C4%90%E1%BB%99ng%20m%E1%BA%A1ch%20v%C3%A0nh%20b%C3%ACnh%20th%C6%B0%E1%BB%9Dng%202.jpeg?raw=true" width="600">
#
# ## **1. Bất thường số 1**
# <img src="https://github.com/VISEF-ISEF-team/VascuIAR/blob/main/imgs/Ph%C3%A1t%20hi%E1%BB%87n%20b%E1%BB%87nh/Anomaly1.jpeg?raw=true" width="600">
#
# #### **1.1 Mô tả bất thường:**
# - Điểm xuất phát và đường đi không bình thường của động mạch vành trái (left coronary artery).
# - Cả động mạch vành phải và động mạch trái đều xuất phát từ xoang vành phải (right coronary sinus) với đường đi xuyên vách (transeptal/intraseptal) của động mạch vành trái, đi qua giữa đường ra thất phải và gốc động mạch chủ.
# - Đây là 1 trong 4 bất thường phổ biển ở động mạch vành thuộc bệnh lý tim người.
#
# ## **Bất thường số 2**
# <img src="https://github.com/VISEF-ISEF-team/VascuIAR/blob/main/imgs/Ph%C3%A1t%20hi%E1%BB%87n%20b%E1%BB%87nh/Anomaly2.jpeg?raw=true" width="600">
#
# #### **2.1 Mô tả bất thường:**
# - Điểm xuất phát và đường đi không bình thường của động mạch vành trái (left coronary artery).
# - Cả động mạch vành phải và động mạch trái đều xuất phát từ xoang vành phải (right coronary sinus) với đường đi xuyên vách (transeptal/intraseptal) của động mạch vành trái, đi qua giữa đường ra thất phải và gốc động mạch chủ.
# - Đây là 1 trong 4 bất thường phổ biển ở động mạch vành thuộc bệnh lý tim người.
#
#
# ## **Bất thường số 3**
# <img src="https://github.com/VISEF-ISEF-team/VascuIAR/blob/main/imgs/Ph%C3%A1t%20hi%E1%BB%87n%20b%E1%BB%87nh/Anomaly3.jpeg?raw=true" width="600">
#
# ## **Bất thường số 4**
#
# #### **4.1 Mô tả bất thường:**
# - Điểm xuất phát và đường đi không bình thường của nhánh Circum flex (LCx) của động mạch vành trái (left coronary artery).
# - Nhánh LCx không đi ra từ động mạch vành trái mà xuất phát từ xoang phải luồn xuống phía dưới và đi lên ở vị trí bên trái.
# - Đây là 1 trong 4 bất thường phổ biển ở động mạch vành thuộc bệnh lý tim người.
#
# #### **4.2 Hậu quả di chứng:**
# - Bất thường đường đi xuyên vách của động mạch vành trái không nguy hiểm nhưng gây ra một số vấn đề sau:
#   + Khiến cho phẩu thuật van động mạch chủ (aortic valve surgery) trở nên khó khăn hoặc rủi ro hơn vì bác sĩ phẫu thuật phải tránh làm tổn thương động mạch vành trái chạy qua vách ngăn.
#   + Nó có thể gây đau ngục (chest pain) hoặc đau thất ngực (angina), đặc biệt là khi tập thể dục vì động mạch vành trái bị chèn ép do sự co bóp tâm thất.
#   + Nó có thể gây rối loạn nhịp tim vì động mạch vành trái có thể kích thích hệ thống điện tim trong vách ngăn.
# - Một số người có thể có đường đi xuyên vách của động mạch vành trái và không bao giờ gặp bất kỳ triệu chứng hoặc vấn đề nào. Những người khác có thể cần điều trị hoặc can thiệp y tế để ngăn ngừa hoặc điều trị các biến chứng. Cách tốt nhất để biết liệu đường đi qua vách ngăn của động mạch vành trái có gây hại cho một người cụ thể hay không là tham khảo ý kiến ​​bác sĩ tim mạch, người có thể thực hiện đánh giá kỹ lưỡng và đưa ra lời khuyên thích hợp

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 4046, done.
# remote: Counting objects: 100% (4046/4046), done.
# remote: Compressing objects: 100% (3073/3073), done.
# remote: Total 4046 (delta 1185), reused 2775 (delta 914), pack-reused 0
# Receiving objects: 100% (4046/4046), 54.69 MiB | 24.92 MiB/s, done.
# Resolving deltas: 100% (1185/1185), done.
# Updating files: 100% (3660/3660), done.

# %%
# %%bash
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf2/setup.py .
# python -m pip install .
# Out:
# Processing /content/models/research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 84.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 59.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 49.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %% [markdown]
# ## Import các thư viện cần thiết

# %%
import numpy as np
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage
import os

from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import colab_utils

import matplotlib
import matplotlib.pyplot as plt

import tensorflow as tf
import cv2
from google.colab.patches import cv2_imshow

# %matplotlib inline

# %% [markdown]
# ## Khám phá bộ dữ liệu

# %%
# Setup các đường dẫn
rootDirPath = '/content/drive/MyDrive/ISEF/VasculAR /Defects Detection/Data'

AnomalyPath = []

AnomalyPath.append(os.path.join(rootDirPath, 'Anomaly 1'))
AnomalyPath.append(os.path.join(rootDirPath, 'Anomaly 2'))
AnomalyPath.append(os.path.join(rootDirPath, 'Anomaly 3'))
AnomalyPath.append(os.path.join(rootDirPath, 'Anomaly 4'))

normalPath = os.path.join(rootDirPath, 'Normal')

# %%
# Đọc một tấm ảnh và chuyển sang numpy array
image = Image.open(os.path.join(defectPath, '1.jpg'))
img = np.array(image)
img.shape
# Out:
# (512, 512, 3)

# %%
# Hàm đọc ảnh thành numpy array
def ConvertToNumpy(path):
  image = Image.open(path)
  imageArray = np.array(image, dtype="uint8")
  return imageArray

# %%
# Đọc các dữ liệu thành numpy array chung
totalImageArray = []

for i in range(4):
  path = AnomalyPath[i]
  array = []
  for file in os.listdir(path):
      imagePath = os.path.join(path, file)
      imageArray = ConvertToNumpy(imagePath)
      array.append(imageArray)

  totalImageArray.append(array)

# %%
print(len(totalImageArray))
print(len(totalImageArray[0]))
print(len(totalImageArray[1]))
print(len(totalImageArray[2]))
print(len(totalImageArray[3]))

# %% [markdown]
# ## Bất thường 1

# %%
# Visualize để quan sát bất thường 1
plt.rcParams["figure.figsize"] = [14, 7]
matplotlib.rc('font', size=10)

plt.suptitle('Bất thường động mạch vành 1', fontsize=16)
for i, imageArray in enumerate(totalImageArray[0]):
  plt.subplot(2, 4, i + 1)
  plt.imshow(imageArray)

plt.show()

# %% [markdown]
# ### Vẽ tọa độ cho bounding box

# %%
gtBoxes = []
colab_utils.annotate(totalImageArray[0], box_storage_pointer=gtBoxes)
# Out:
# '--boxes array populated--'

# %%
gtBoxes
# Out:
# [array([[0.37941288, 0.28244275, 0.43107954, 0.36895674]]),
#  array([[0.37107954, 0.27827192, 0.42441288, 0.36975858]]),
#  array([[0.37274621, 0.27330779, 0.42941288, 0.37931034]]),
#  array([[0.38441288, 0.25831202, 0.44941288, 0.3797954 ]]),
#  array([[0.56441288, 0.40609137, 0.63941288, 0.68527919]]),
#  array([[0.57274621, 0.36173633, 0.65107954, 0.4807074 ]]),
#  array([[0.54107954, 0.58649094, 0.61607954, 0.68369028]])]

# %%
np.save(os.path.join(rootDirPath,"BBoxCoordinates_Anomaly1"), gtBoxes)

# %%
import matplotlib.pyplot as plt

matplotlib.rc('font', size=10)

# Lặp qua các ảnh
for i in range(7):
    # Create subplots with 2 rows and 4 columns
    plt.subplot(2, 4, i + 1)

    # Copy image array
    imageArrayWithAnnotations = totalImageArray[0][i].copy()

    # Vẽ bounding box và nhãn trên ảnh
    viz_utils.visualize_boxes_and_labels_on_image_array(
        imageArrayWithAnnotations,
        gtBoxes[i],
        np.ones(shape=[gtBoxes[i].shape[0]], dtype=np.int32),
        np.array([1.0], dtype=np.float32),
        {1: {'id': 1, 'name': 'Bat thuong dong mach vanh 1'}},
        use_normalized_coordinates=True,
        min_score_thresh=0.8
    )

    # Hiển thị hình ảnh
    plt.imshow(imageArrayWithAnnotations)
    plt.title(f'Hình {i+1}')

# Điều chỉnh layout tránh overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Bất thường 2

# %%
# Visualize để quan sát bất thường 1
plt.rcParams["figure.figsize"] = [14, 7]
matplotlib.rc('font', size=10)

plt.suptitle('Bất thường động mạch vành 2', fontsize=16)
for i, imageArray in enumerate(totalImageArray[1]):
  plt.subplot(2, 3, i + 1)
  plt.imshow(imageArray)

plt.show()

# %%
gtBoxes1 = []
colab_utils.annotate(totalImageArray[1], box_storage_pointer=gtBoxes)
# Out:
# '--boxes array populated--'

# %%
np.save(os.path.join(rootDirPath,"BBoxCoordinates_Anomaly2"), gtBoxes1)

# %%
import matplotlib.pyplot as plt

matplotlib.rc('font', size=10)

# Lặp qua các ảnh
for i in range(5):
    # Create subplots with 2 rows and 4 columns
    plt.subplot(1, 5, i + 1)

    # Copy image array
    imageArrayWithAnnotations = totalImageArray[1][i].copy()

    # Vẽ bounding box và nhãn trên ảnh
    viz_utils.visualize_boxes_and_labels_on_image_array(
        imageArrayWithAnnotations,
        gtBoxes[i],
        np.ones(shape=[gtBoxes[i].shape[0]], dtype=np.int32),
        np.array([1.0], dtype=np.float32),
        {1: {'id': 1, 'name': 'Bat thuong dong mach vanh 2'}},
        use_normalized_coordinates=True,
        min_score_thresh=0.8
    )

    # Hiển thị hình ảnh
    plt.imshow(imageArrayWithAnnotations)
    plt.title(f'Hình {i+1}')

# Điều chỉnh layout tránh overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Bất thường 3

# %%
# Visualize để quan sát bất thường 3
plt.rcParams["figure.figsize"] = [14, 7]
matplotlib.rc('font', size=10)

plt.suptitle('Bất thường động mạch vành 3', fontsize=16)
for i, imageArray in enumerate(totalImageArray[2]):
  plt.subplot(2, 3, i + 1)
  plt.imshow(imageArray)

plt.show()

# %%
gtBoxes2 = []
colab_utils.annotate(totalImageArray[2], box_storage_pointer=gtBoxes)
# Out:
# '--boxes array populated--'

# %%
np.save(os.path.join(rootDirPath,"BBoxCoordinates_Anomaly3"), gtBoxes2)

# %%
import matplotlib.pyplot as plt

matplotlib.rc('font', size=10)

# Lặp qua các ảnh
for i in range(6):
    # Create subplots with 2 rows and 4 columns
    plt.subplot(2, 3, i + 1)

    # Copy image array
    imageArrayWithAnnotations = totalImageArray[2][i].copy()

    # Vẽ bounding box và nhãn trên ảnh
    viz_utils.visualize_boxes_and_labels_on_image_array(
        imageArrayWithAnnotations,
        gtBoxes[i],
        np.ones(shape=[gtBoxes[i].shape[0]], dtype=np.int32),
        np.array([1.0], dtype=np.float32),
        {1: {'id': 1, 'name': 'Bat thuong dong mach vanh 3'}},
        use_normalized_coordinates=True,
        min_score_thresh=0.8
    )

    # Hiển thị hình ảnh
    plt.imshow(imageArrayWithAnnotations)
    plt.title(f'Hình {i+1}')

# Điều chỉnh layout tránh overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Hàm để vẽ lại Bounding Box sau khi predict

# %%
# Giá trị thục của bounding box
a = np.array(gtBoxes[0][0]) * 512
ymin, xmin, ymax, xmax = a
ymin = round(ymin)
xmin = round(xmin)
ymax = round(ymax)
xmax = round(xmax)
print(ymin, xmin, ymax, xmax)
# Out:
# 222 198 256 285

# %%
# Đọc ảnh
image = cv2.imread(os.path.join(defectPath, "1.jpg"))

# %%
# Hiển thị ảnh với bounding box
cv2.rectangle(image, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
