# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage
import os

import matplotlib
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow

import cv2

# %%
import tensorflow.keras.applications as model_zoo

BaseModel = model_zoo.MobileNetV3Small(include_top=False,
                                        weights='imagenet',
                                        alpha=0.75,
                                        pooling="avg")
BaseModel.trainable = False # freeze pretrained weights
BaseModel.training=False # set to inference mode
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
rootDirPath = "/content/drive/MyDrive/CoronaryArtery"
defectPath = os.path.join(rootDirPath, "Defect")
normalPath = os.path.join(rootDirPath, "Ordinary")

# %%
image = Image.open(os.path.join(defectPath, "image_1.jpg"))
imageArray = np.array(image)
print(imageArray.shape)
# Out:
# (512, 512, 3)

# %%
imageArrayExpand = np.expand_dims(imageArray, axis=0)
embedding = BaseModel(imageArrayExpand, training=False)
print(embedding.shape)
# Out:
# (1, 432)

# %%
def CreateBinaryData():
  """
  1: class WITH coronary artery defects
  0: class WITH NO coronary artery defect
  """

  y_train = []
  x_train = []

  for pathTrue, pathFalse in zip(os.listdir(defectPath), os.listdir(normalPath)):

    imageTrue = np.array(Image.open(os.path.join(defectPath, pathTrue)))
    imageFalse = np.array(Image.open(os.path.join(normalPath, pathFalse)).convert("RGB"))

    imageTrue = np.expand_dims(imageTrue, axis=0)
    imageFalse = np.expand_dims(imageFalse, axis=0)

    imageTrue = BaseModel(imageTrue, training=False)[0]
    imageFalse = BaseModel(imageFalse, training=False)[0]

    x_train.append(imageTrue)
    x_train.append(imageFalse)

    y_train.append(1)
    y_train.append(0)

  x_train = np.array(x_train)
  y_train = np.array(y_train)

  return x_train, y_train

# %%
x_train, y_train = CreateBinaryData()

# %%
print(x_train.shape, y_train.shape)
# Out:
# (6, 432) (6,)

# %% [markdown]
# ## BINARY CLASSIFICATION

# %%
BinaryClassificationModel = tf.keras.Sequential()
input_layer = tf.keras.layers.Input(shape=(432))
output_layer = tf.keras.layers.Dense(1, activation="sigmoid")
BinaryClassificationModel.add(input_layer)
BinaryClassificationModel.add(output_layer)
BinaryClassificationModel.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = BinaryClassificationModel.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 497ms/step - loss: 0.9723 - accuracy: 0.5000
# Epoch 2/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8730 - accuracy: 0.5000
# Epoch 3/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7838 - accuracy: 0.5000
# Epoch 4/10
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7060 - accuracy: 0.5000
# Epoch 5/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6408 - accuracy: 0.5000
# Epoch 6/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5883 - accuracy: 0.5000
# Epoch 7/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5478 - accuracy: 0.6667
# Epoch 8/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5177 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4958 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4797 - accuracy: 1.0000

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].set_title("Độ chính xác")
axes[0].plot(history.history["accuracy"])
axes[1].set_title("Hàm mất mát")
axes[1].plot(history.history["loss"])

# %%
BinaryClassificationModel.save('/content/drive/MyDrive/BinaryClassificationModel.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
InferModel = tf.keras.Sequential()

InferModel.add(BaseModel)
InferModel.add(BinaryClassificationModel)

# %% [markdown]
# ## BOUNDING BOX REGRESSION

# %%
def CreateDataForBBox():
  x_train_bbox = []
  y_train_bbox = []

  for pathTrue in os.listdir(defectPath):
    imageTrue = np.array(Image.open(os.path.join(defectPath, pathTrue)))
    imageTrue = np.expand_dims(imageTrue, axis=0)
    imageTrue = BaseModel(imageTrue, training=False)[0]

    x_train_bbox.append(imageTrue)

  # [ymin, xmin, ymax, xmax]
  y_load = np.load("/content/drive/MyDrive/BBoxCoordinates.npy")

  for i in range(y_load.shape[0]):
    for j in range(y_load.shape[1]):
      a = np.array(y_load[i][j])
      a *= 512
      a = np.round(a)
      print(a)
      y_train_bbox.append(a)

  x_train_bbox = np.array(x_train_bbox)
  y_train_bbox = np.array(y_train_bbox)

  return x_train_bbox, y_train_bbox

# %%
x_train_bbox, y_train_bbox = CreateDataForBBox()

print(x_train_bbox.shape, y_train_bbox.shape)
# Out:
# [220. 196. 255. 285.]
# [199. 170. 240. 219.]
# [198. 171. 250. 273.]
# (3, 432) (3, 4)

# %%
ModelRegression = tf.keras.models.Sequential()
input_layer_reg = tf.keras.layers.Input(shape=(432))
output_layer_reg = tf.keras.layers.Dense(4, activation="linear")
ModelRegression.add(input_layer_reg)
ModelRegression.add(output_layer_reg)
# compile the model with an optimizer and loss function
ModelRegression.compile(optimizer='adam', loss='mae', metrics=['mse'])
ModelRegression.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 4)                 1732
#
# =================================================================
# Total params: 1732 (6.77 KB)
# Trainable params: 1732 (6.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
historyRegression = ModelRegression.fit(x_train_bbox, y_train_bbox, epochs=300)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0212 - mse: 4.9167e-04
# Epoch 2/300
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0253 - mse: 6.6566e-04
# Epoch 3/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0263 - mse: 9.8805e-04
# Epoch 4/300
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0246 - mse: 7.2177e-04
# Epoch 5/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0267 - mse: 9.1758e-04
# Epoch 6/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0269 - mse: 8.2547e-04
# Epoch 7/300
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0128 - mse: 2.0777e-04
# Epoch 8/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0171 - mse: 4.3520e-04
# Epoch 9/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0228 - mse: 6.9094e-04
# Epoch 10/300
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0217 - mse: 5.8368e-04
# Epoch 11/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0290 - mse: 0.0010
# Epoch 12/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0287 - mse: 9.8747e-04
# Epoch 13/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0169 - mse: 3.2022e-04
# Epoch 14/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0292 - mse: 9.1926e-04
# Epoch 15/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0298 - mse: 0.0013
# Epoch 16/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0278 - mse: 9.5480e-04
# Epoch 17/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0248 - mse: 8.9297e-04
# Epoch 18/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0338 - mse: 0.0013
# Epoch 19/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0257 - mse: 0.0010
# Epoch 20/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0261 - mse: 8.1476e-04
# Epoch 21/300
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0199 - mse: 6.1747e-04
# Epoch 22/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0242 - mse: 6.4828e-04
# Epoch 23/300
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0216 - mse: 8.0125e-04
# Epoch 24/300
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0228 - mse: 7.0304e-04
# Epoch 25/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0157 - mse: 2.9783e-04
# Epoch 26/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0208 - mse: 5.2257e-04
# Epoch 27/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0182 - mse: 5.4597e-04
# Epoch 28/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0176 - mse: 4.8727e-04
# Epoch 29/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0278 - mse: 9.4326e-04
# Epoch 30/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0229 - mse: 7.4834e-04
# Epoch 31/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0165 - mse: 3.0250e-04
# Epoch 32/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0188 - mse: 4.5536e-04
# Epoch 33/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0254 - mse: 8.0824e-04
# Epoch 34/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0282 - mse: 8.5249e-04
# Epoch 35/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0238 - mse: 8.2310e-04
# Epoch 36/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0302 - mse: 0.0011
# Epoch 37/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0288 - mse: 0.0011
# Epoch 38/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0302 - mse: 0.0010
# Epoch 39/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0161 - mse: 5.1697e-04
# Epoch 40/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0331 - mse: 0.0015
# Epoch 41/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0480 - mse: 0.0032
# Epoch 42/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0461 - mse: 0.0030
# Epoch 43/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0273 - mse: 0.0012
# Epoch 44/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0181 - mse: 4.4312e-04
# Epoch 45/300
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0365 - mse: 0.0019
# Epoch 46/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0486 - mse: 0.0039
# Epoch 47/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0527 - mse: 0.0047
# Epoch 48/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0459 - mse: 0.0034
# Epoch 49/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0283 - mse: 0.0011
# Epoch 50/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0230 - mse: 5.7356e-04
# Epoch 51/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0284 - mse: 0.0012
# Epoch 52/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0306 - mse: 0.0012
# Epoch 53/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0312 - mse: 0.0011
# Epoch 54/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0287 - mse: 8.9832e-04
# Epoch 55/300
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0222 - mse: 6.6558e-04
# Epoch 56/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0240 - mse: 6.6429e-04
# Epoch 57/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0207 - mse: 6.2918e-04
# Epoch 58/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0240 - mse: 6.3991e-04
# Epoch 59/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0228 - mse: 8.0772e-04
# Epoch 60/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0206 - mse: 6.6753e-04
# Epoch 61/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0186 - mse: 3.6952e-04
# Epoch 62/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0211 - mse: 5.2639e-04
# Epoch 63/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0230 - mse: 7.4440e-04
# Epoch 64/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0258 - mse: 8.0222e-04
# Epoch 65/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0269 - mse: 9.1984e-04
# Epoch 66/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0326 - mse: 0.0012
# Epoch 67/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0257 - mse: 0.0010
# Epoch 68/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0271 - mse: 8.9708e-04
# Epoch 69/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0188 - mse: 6.0339e-04
# Epoch 70/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0309 - mse: 0.0011
# Epoch 71/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0357 - mse: 0.0016
# Epoch 72/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0295 - mse: 0.0010
# Epoch 73/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0157 - mse: 2.9700e-04
# Epoch 74/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0236 - mse: 5.9057e-04
# Epoch 75/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0156 - mse: 5.1143e-04
# Epoch 76/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0199 - mse: 5.1894e-04
# Epoch 77/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0257 - mse: 8.9758e-04
# Epoch 78/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0242 - mse: 7.5420e-04
# Epoch 79/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0141 - mse: 2.2629e-04
# Epoch 80/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0169 - mse: 4.2980e-04
# Epoch 81/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0218 - mse: 6.5354e-04
# Epoch 82/300
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0200 - mse: 5.6495e-04
# Epoch 83/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0264 - mse: 9.0193e-04
# Epoch 84/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0222 - mse: 6.8688e-04
# Epoch 85/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0212 - mse: 4.8881e-04
# Epoch 86/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0275 - mse: 7.9455e-04
# Epoch 87/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0178 - mse: 5.3274e-04
# Epoch 88/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0273 - mse: 9.1816e-04
# Epoch 89/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0387 - mse: 0.0017
# Epoch 90/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0336 - mse: 0.0012
# Epoch 91/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0120 - mse: 1.9845e-04
# Epoch 92/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0324 - mse: 0.0015
# Epoch 93/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0420 - mse: 0.0029
# Epoch 94/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0432 - mse: 0.0028
# Epoch 95/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0373 - mse: 0.0018
# Epoch 96/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0215 - mse: 6.7386e-04
# Epoch 97/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0323 - mse: 0.0016
# Epoch 98/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0480 - mse: 0.0039
# Epoch 99/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0467 - mse: 0.0044
# Epoch 100/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0430 - mse: 0.0032
# Epoch 101/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0382 - mse: 0.0017
# Epoch 102/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0264 - mse: 8.0400e-04
# Epoch 103/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0243 - mse: 8.6702e-04
# Epoch 104/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0299 - mse: 0.0012
# Epoch 105/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0252 - mse: 8.0016e-04
# Epoch 106/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0258 - mse: 7.1646e-04
# Epoch 107/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0321 - mse: 0.0013
# Epoch 108/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0274 - mse: 8.9437e-04
# Epoch 109/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0166 - mse: 3.1150e-04
# Epoch 110/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0233 - mse: 5.8173e-04
# Epoch 111/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0168 - mse: 5.1610e-04
# Epoch 112/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0177 - mse: 4.8629e-04
# Epoch 113/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0286 - mse: 9.6812e-04
# Epoch 114/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0244 - mse: 7.5579e-04
# Epoch 115/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0189 - mse: 4.2769e-04
# Epoch 116/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0251 - mse: 7.4349e-04
# Epoch 117/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0209 - mse: 6.2807e-04
# Epoch 118/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0297 - mse: 9.6981e-04
# Epoch 119/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0356 - mse: 0.0016
# Epoch 120/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0305 - mse: 0.0011
# Epoch 121/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0147 - mse: 2.8736e-04
# Epoch 122/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0302 - mse: 0.0010
# Epoch 123/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0296 - mse: 0.0013
# Epoch 124/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0266 - mse: 8.6537e-04
# Epoch 125/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0257 - mse: 8.9598e-04
# Epoch 126/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0269 - mse: 8.1955e-04
# Epoch 127/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0115 - mse: 1.9582e-04
# Epoch 128/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0192 - mse: 4.6036e-04
# Epoch 129/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0197 - mse: 6.0490e-04
# Epoch 130/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0213 - mse: 5.7435e-04
# Epoch 131/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0240 - mse: 8.2466e-04
# Epoch 132/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0203 - mse: 6.5826e-04
# Epoch 133/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0177 - mse: 3.3795e-04
# Epoch 134/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0194 - mse: 5.0602e-04
# Epoch 135/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0204 - mse: 6.0964e-04
# Epoch 136/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0194 - mse: 5.0734e-04
# Epoch 137/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0312 - mse: 0.0011
# Epoch 138/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0309 - mse: 0.0010
# Epoch 139/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0137 - mse: 2.1779e-04
# Epoch 140/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0266 - mse: 8.5959e-04
# Epoch 141/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0327 - mse: 0.0015
# Epoch 142/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0307 - mse: 0.0011
# Epoch 143/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0219 - mse: 7.9685e-04
# Epoch 144/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0357 - mse: 0.0017
# Epoch 145/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0379 - mse: 0.0026
# Epoch 146/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0425 - mse: 0.0027
# Epoch 147/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0313 - mse: 0.0015
# Epoch 148/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0187 - mse: 4.9516e-04
# Epoch 149/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0423 - mse: 0.0022
# Epoch 150/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0513 - mse: 0.0041
# Epoch 151/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0426 - mse: 0.0041
# Epoch 152/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0423 - mse: 0.0032
# Epoch 153/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0322 - mse: 0.0014
# Epoch 154/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0236 - mse: 6.2544e-04
# Epoch 155/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0342 - mse: 0.0015
# Epoch 156/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0333 - mse: 0.0014
# Epoch 157/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0211 - mse: 4.8650e-04
# Epoch 158/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0251 - mse: 6.5740e-04
# Epoch 159/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0261 - mse: 9.7020e-04
# Epoch 160/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0245 - mse: 7.1662e-04
# Epoch 161/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0265 - mse: 9.0948e-04
# Epoch 162/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0267 - mse: 8.0869e-04
# Epoch 163/300
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0127 - mse: 2.0320e-04
# Epoch 164/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0170 - mse: 4.2731e-04
# Epoch 165/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0226 - mse: 6.7358e-04
# Epoch 166/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0216 - mse: 5.7862e-04
# Epoch 167/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0288 - mse: 0.0010
# Epoch 168/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0285 - mse: 9.7014e-04
# Epoch 169/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0168 - mse: 3.1562e-04
# Epoch 170/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0290 - mse: 9.1030e-04
# Epoch 171/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0296 - mse: 0.0013
# Epoch 172/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0277 - mse: 9.4939e-04
# Epoch 173/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0246 - mse: 8.8465e-04
# Epoch 174/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0335 - mse: 0.0012
# Epoch 175/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0256 - mse: 0.0010
# Epoch 176/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0260 - mse: 8.0591e-04
# Epoch 177/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0197 - mse: 6.0075e-04
# Epoch 178/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0241 - mse: 6.4321e-04
# Epoch 179/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0214 - mse: 7.9304e-04
# Epoch 180/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0226 - mse: 6.8659e-04
# Epoch 181/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0156 - mse: 2.9330e-04
# Epoch 182/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0206 - mse: 5.1447e-04
# Epoch 183/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0180 - mse: 5.2928e-04
# Epoch 184/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0175 - mse: 4.8258e-04
# Epoch 185/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0277 - mse: 9.3518e-04
# Epoch 186/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0227 - mse: 7.3234e-04
# Epoch 187/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0164 - mse: 2.9785e-04
# Epoch 188/300
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0187 - mse: 4.4730e-04
# Epoch 189/300
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0252 - mse: 7.9113e-04
# Epoch 190/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0280 - mse: 8.4703e-04
# Epoch 191/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0236 - mse: 8.1498e-04
# Epoch 192/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0300 - mse: 0.0011
# Epoch 193/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0287 - mse: 0.0011
# Epoch 194/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0300 - mse: 9.9535e-04
# Epoch 195/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0159 - mse: 5.0044e-04
# Epoch 196/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0329 - mse: 0.0015
# Epoch 197/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0479 - mse: 0.0032
# Epoch 198/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0459 - mse: 0.0030
# Epoch 199/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0272 - mse: 0.0012
# Epoch 200/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0180 - mse: 4.3512e-04
# Epoch 201/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0362 - mse: 0.0019
# Epoch 202/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0485 - mse: 0.0039
# Epoch 203/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0525 - mse: 0.0047
# Epoch 204/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0457 - mse: 0.0034
# Epoch 205/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0281 - mse: 0.0011
# Epoch 206/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0229 - mse: 5.6551e-04
# Epoch 207/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0282 - mse: 0.0012
# Epoch 208/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0305 - mse: 0.0012
# Epoch 209/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0311 - mse: 0.0011
# Epoch 210/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0285 - mse: 8.8253e-04
# Epoch 211/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0221 - mse: 6.6077e-04
# Epoch 212/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0238 - mse: 6.5603e-04
# Epoch 213/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0205 - mse: 6.1246e-04
# Epoch 214/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0239 - mse: 6.3538e-04
# Epoch 215/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0226 - mse: 8.0037e-04
# Epoch 216/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0204 - mse: 6.5201e-04
# Epoch 217/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0185 - mse: 3.6495e-04
# Epoch 218/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0209 - mse: 5.1859e-04
# Epoch 219/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0228 - mse: 7.2798e-04
# Epoch 220/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0257 - mse: 7.9691e-04
# Epoch 221/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0267 - mse: 9.1225e-04
# Epoch 222/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0324 - mse: 0.0011
# Epoch 223/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0256 - mse: 0.0010
# Epoch 224/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0270 - mse: 8.8890e-04
# Epoch 225/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0186 - mse: 5.8770e-04
# Epoch 226/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0307 - mse: 0.0011
# Epoch 227/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0355 - mse: 0.0016
# Epoch 228/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0293 - mse: 0.0010
# Epoch 229/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0156 - mse: 2.9275e-04
# Epoch 230/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0234 - mse: 5.8320e-04
# Epoch 231/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0154 - mse: 4.9603e-04
# Epoch 232/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0198 - mse: 5.1447e-04
# Epoch 233/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0255 - mse: 8.8982e-04
# Epoch 234/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0240 - mse: 7.3891e-04
# Epoch 235/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0140 - mse: 2.2207e-04
# Epoch 236/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0168 - mse: 4.2194e-04
# Epoch 237/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0216 - mse: 6.3778e-04
# Epoch 238/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0199 - mse: 5.6049e-04
# Epoch 239/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0263 - mse: 8.9431e-04
# Epoch 240/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0220 - mse: 6.7180e-04
# Epoch 241/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0211 - mse: 4.8421e-04
# Epoch 242/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0273 - mse: 7.8626e-04
# Epoch 243/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0176 - mse: 5.1733e-04
# Epoch 244/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0272 - mse: 9.1300e-04
# Epoch 245/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0386 - mse: 0.0017
# Epoch 246/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0334 - mse: 0.0012
# Epoch 247/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0119 - mse: 1.9444e-04
# Epoch 248/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0322 - mse: 0.0015
# Epoch 249/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0418 - mse: 0.0029
# Epoch 250/300
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0431 - mse: 0.0028
# Epoch 251/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0371 - mse: 0.0018
# Epoch 252/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0213 - mse: 6.5905e-04
# Epoch 253/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0322 - mse: 0.0016
# Epoch 254/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0478 - mse: 0.0039
# Epoch 255/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0465 - mse: 0.0044
# Epoch 256/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0429 - mse: 0.0032
# Epoch 257/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0381 - mse: 0.0017
# Epoch 258/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0262 - mse: 7.8905e-04
# Epoch 259/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0241 - mse: 8.6164e-04
# Epoch 260/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0298 - mse: 0.0012
# Epoch 261/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0250 - mse: 7.8459e-04
# Epoch 262/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0257 - mse: 7.1240e-04
# Epoch 263/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0320 - mse: 0.0013
# Epoch 264/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0272 - mse: 8.7994e-04
# Epoch 265/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0165 - mse: 3.0751e-04
# Epoch 266/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0232 - mse: 5.7442e-04
# Epoch 267/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0166 - mse: 5.0141e-04
# Epoch 268/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0176 - mse: 4.8241e-04
# Epoch 269/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0285 - mse: 9.6115e-04
# Epoch 270/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0243 - mse: 7.4170e-04
# Epoch 271/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0188 - mse: 4.2341e-04
# Epoch 272/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0250 - mse: 7.3579e-04
# Epoch 273/300
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0207 - mse: 6.1340e-04
# Epoch 274/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0296 - mse: 9.6562e-04
# Epoch 275/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0355 - mse: 0.0016
# Epoch 276/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0303 - mse: 0.0011
# Epoch 277/300
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0146 - mse: 2.8345e-04
# Epoch 278/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0300 - mse: 0.0010
# Epoch 279/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0295 - mse: 0.0013
# Epoch 280/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0266 - mse: 8.6134e-04
# Epoch 281/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0256 - mse: 8.8890e-04
# Epoch 282/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0268 - mse: 8.0586e-04
# Epoch 283/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0114 - mse: 1.9209e-04
# Epoch 284/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0191 - mse: 4.5302e-04
# Epoch 285/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0195 - mse: 5.9010e-04
# Epoch 286/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0212 - mse: 5.7053e-04
# Epoch 287/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0239 - mse: 8.1807e-04
# Epoch 288/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0201 - mse: 6.4461e-04
# Epoch 289/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0176 - mse: 3.3417e-04
# Epoch 290/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0192 - mse: 4.9904e-04
# Epoch 291/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0203 - mse: 5.9465e-04
# Epoch 292/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0193 - mse: 5.0351e-04
# Epoch 293/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0310 - mse: 0.0011
# Epoch 294/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0307 - mse: 0.0010
# Epoch 295/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0136 - mse: 2.1396e-04
# Epoch 296/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0265 - mse: 8.5116e-04
# Epoch 297/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0325 - mse: 0.0014
# Epoch 298/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0306 - mse: 0.0011
# Epoch 299/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0218 - mse: 7.9028e-04
# Epoch 300/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0356 - mse: 0.0017

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].set_title("Độ lệch MAE")
axes[0].plot(historyRegression.history["mse"])
axes[1].set_title("Độ lệch MSE")
axes[1].plot(historyRegression.history["mae"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-176-e2505d60098d> in <cell line: 5>()
#       3 axes[0].plot(historyRegression.history["mse"])
#       4 axes[1].set_title("Độ lệch MSE")
# ----> 5 axes[1].plot(historyRegression.history["mae"])
#
# KeyError: 'mae'

# %%
RegressionModel = tf.keras.models.Sequential()
RegressionModel.add(BaseModel)
RegressionModel.add(ModelRegression)

# %%
image = cv2.imread(os.path.join(defectPath, "image_1.jpg"))
imageArray = np.array(image)
imageArrayExpand = np.expand_dims(imageArray, axis=0)
predictions = RegressionModel.predict(imageArrayExpand)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
predictions = np.array(predictions[0])
ymin, xmin, ymax, xmax = predictions
ymin = round(ymin)
xmin = round(xmin)
ymax = round(ymax)
xmax = round(xmax)

print(ymin, xmin, ymax, xmax)
# Out:
# 220 196 255 285

# %%
from google.colab.patches import cv2_imshow
cv2.rectangle(image, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)

# Display the image with the bounding box
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
ModelRegression.save("/content/drive/MyDrive/ModelRegression.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
